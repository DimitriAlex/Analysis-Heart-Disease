# %%
import numpy as np

# %%
def a () :
    c = input('User : ')

# %%
a()
# Out:
# User : ayam

# %%
def valid(gg) :
    c1_len = np.arange(29, 77, 1)
    length = -1
    while length not in c1_len:
        try:
             length = gg     
        except ValueError:
             print("Not an integer!")
             continue
        else:
            if length not in c1_len:
                print("Length not accepted, try again")
            print(length)

# %%
valid(a())
# Out:
# User : 3
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# Length not accepted, try again
# None
# ...

# %%
factorial(14)
# Out:
# 87178291200

# %%
factorial(-asd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11744\3573779827.py in <module>
# ----> 1 factorial(-asd)
#
# NameError: name 'asd' is not defined

# %%
 c2_len =[0,1]
    c3_len =[0,3]
    c4_len =[94,200]
    c5_len =[51,564]
    c6_len =[0,1]
    c7_len =[0,2]
    c8_len =[71,202]
    c9_len =[0,1]
    c10_len =[0,6.2]
    c11_len =[0,2]
    c12_len =[0,4]
    c13_len =[0,3]
    length = -1

# %%
c1_len =np.arange(29, 78, 1)
length = -1   
while length not in c1_len:
    length = int(input("[+]:Select the length you want for your key: "))
    if length not in c1_len:
         print("Length not accepted, try again")
    print(length)

# %%
c1_len =np.arange(29, 78, 1)
jj = -1
while jj not in c1_len:
    try:
         jj = int(input("Umur (29-77): "))       
    except ValueError:
         print("Harap Masukkan Angka")
         continue
    else:
        if jj not in c1_len:
            print("Harap Pilih Angka yang Tersedia")
        print(jj)
    return jj
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_11744\375356725.py", line 13
#     return jj
#     ^
# SyntaxError: 'return' outside function
